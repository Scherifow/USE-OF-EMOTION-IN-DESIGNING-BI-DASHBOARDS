# %%
import pandas as pd
import seaborn
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('ToJupy.xlsx')

# %%
data
# Out:
#   Návrh  Number\n of\nelements  Time\n⌀  Appearance\n⌀  Clarity\n⌀  Happy\n⌀  \
# 0  obr1                    223    33.25          4.900        4.35  0.103639
# 1  obr2                    215    22.55          3.450        5.75  0.094025
# 2  obr3                    215    17.40          5.100        6.70  0.079134
# 3  obr4                    159    18.00          7.200        7.30  0.073590
# 4  obr5                     42    14.00          8.925        8.85  0.152395
# 5  obr6                    173    22.00          7.100        6.70  0.059985
#
#     Sad\n⌀   Angry \n⌀  Surprised\n ⌀   Scared\n⌀  Disgusted\n ⌀
# 0  0.048672   0.099521        0.027599   0.011120       0.038625
# 1  0.059276   0.079896        0.021245   0.024386       0.043352
# 2  0.053845   0.115873        0.019611   0.025153       0.023507
# 3  0.049488   0.054787        0.028422   0.013840       0.027402
# 4  0.037989   0.066944        0.018766   0.015907       0.036526
# ...

# %%
data.corr()
corel_data=data.corr()
corel_data_csv = round(corel_data, 3)
corel_data.to_csv("result.csv")

# %%
plt.figure(figsize=(15,10))
seaborn.heatmap(data.corr(), annot = True, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,7))
seaborn.heatmap(data.corr(), annot = True, cmap="binary", cbar = False)
# Out:
# <AxesSubplot:>
